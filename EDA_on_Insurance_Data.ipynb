# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali8089/Data_Science-and-ML/blob/EDAs/EDA_on_Insurance_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #EDA on Insurance Data

# %%
# Import dependencies

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import dataset

# %%
df = pd.read_csv('/content/insurance_data - insurance_data.csv')

# %%
df.head()
# Out:
#    index  PatientID   age gender   bmi  bloodpressure diabetic  children  \
# 0      0          1  39.0   male  23.2             91      Yes         0
# 1      1          2  24.0   male  30.1             87       No         0
# 2      2          3   NaN   male  33.3             82      Yes         0
# 3      3          4   NaN   male  33.7             80       No         0
# 4      4          5   NaN   male  34.1            100       No         0
#
#   smoker     region    claim
# 0     No  southeast  1121.87
# 1     No  southeast  1131.51
# 2     No  southeast  1135.94
# 3     No  northwest  1136.40
# 4     No  northwest  1137.01

# %%
df.isnull().sum()
# Out:
# index            0
# PatientID        0
# age              5
# gender           0
# bmi              0
# bloodpressure    0
# diabetic         0
# children         0
# smoker           0
# region           3
# claim            0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [index, PatientID, age, gender, bmi, bloodpressure, diabetic, children, smoker, region, claim]
# Index: []

# %%
df = df.dropna(how='any')

# %% [markdown]
# # Univariate Analysis
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# Steps of doing Univariate Analysis on Numerical columns
# 1. Descriptive Statistics: Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# 2. Visualizations: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# 3. Identifying Outliers: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# 4. Skewness: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# 5. Conclusion: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# AGE
#
# Conclusions:
# 1. Bimodal distribution(around 25 and 45)
# 2. Almost no outliers

# %%
df['age'].describe()
# Out:
# count    1332.000000
# mean       38.086336
# std        11.112804
# min        18.000000
# 25%        29.000000
# 50%        38.000000
# 75%        47.000000
# max        60.000000
# Name: age, dtype: float64

# %%
df['age'].plot(kind='hist',bins=40)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['age'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['age'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['age'].skew()
# Out:
# np.float64(0.11172909283724285)

# %% [markdown]
# GENDER
#
# Conclusions:
# 1. Almost equally distributed male and female

# %%
df['gender'].value_counts()
# Out:
# gender
# male      670
# female    662
# Name: count, dtype: int64

# %%
df['gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %%
df['gender'].value_counts().plot(kind='pie',autopct = '%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# BMI
#
# Conclusions:
# 1. Normally distributed (mean= 30.65, std = 6.11)
# 2. Outliers on the larger side(>34)

# %%
df['bmi'].describe()
# Out:
# count    1332.000000
# mean       30.658333
# std         6.118967
# min        16.000000
# 25%        26.200000
# 50%        30.350000
# 75%        34.725000
# max        53.100000
# Name: bmi, dtype: float64

# %%
df['bmi'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['bmi'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['bmi'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['bmi'].skew()
# Out:
# np.float64(0.2898954505935464)

# %% [markdown]
# BLOODPRESSURE
#
# Conclusions
# 1. Right Skewed
# 2. Outliers on the greater side

# %%
df['bloodpressure'].describe()
# Out:
# count    1332.000000
# mean       94.189189
# std        11.445173
# min        80.000000
# 25%        86.000000
# 50%        92.000000
# 75%        99.000000
# max       140.000000
# Name: bloodpressure, dtype: float64

# %%
df['bloodpressure'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['bloodpressure'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['bloodpressure'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['bloodpressure'].skew()
# Out:
# np.float64(1.4838579128667744)

# %% [markdown]
# DIABETIC
#
# Conclusions:
#
# 1. More Diabetic People than Non Diabetic(Not Much Almost equal)

# %%
df['diabetic'].value_counts()
# Out:
# diabetic
# No     695
# Yes    637
# Name: count, dtype: int64

# %%
df['diabetic'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='diabetic'>

# %%
df['diabetic'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# CHILDREN
#
# Conclusion:
# 1. Most People don't have children
# 2. Then people with 1,2,3 children
# 3. Very few people with 4 to 5 children

# %%
df['children'].value_counts()
# Out:
# children
# 0    568
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
df['children'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='children'>

# %%
df['children'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# SMOKER
#
# Conclusions:
#
# 1. Most people don't smoke

# %%
df['smoker'].value_counts()
# Out:
# smoker
# No     1058
# Yes     274
# Name: count, dtype: int64

# %%
df['smoker'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='smoker'>

# %%
df['smoker'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# REGION
#
# Conclusions:
#
# Most people are from southeast and the least from northeast

# %%
df['region'].value_counts()
# Out:
# region
# southeast    442
# northwest    345
# southwest    314
# northeast    231
# Name: count, dtype: int64

# %%
df['region'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='region'>

# %% [markdown]
# CLAIM
#
# Conclusions:
# 1. Right Skewed
# 2. Outliers mostly on the greater side (>50k)

# %%
df['claim'].describe()
# Out:
# count     1332.000000
# mean     13325.246426
# std      12109.620712
# min       1121.870000
# 25%       4760.157500
# 50%       9412.965000
# 75%      16781.327500
# max      63770.430000
# Name: claim, dtype: float64

# %%
df['claim'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['claim'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['claim'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['claim'].skew()
# Out:
# np.float64(1.513847422927789)

# %% [markdown]
# #Bivariate Analysis
#
# Select 2 cols
#
# Understand type of relationship
#
# **Numerical - Numerical**
#
# a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots
#
# b. Check correlation coefficent to check linear relationship
#
#
# **Numerical - Categorical **- create visualizations that compare the distribution of the numerical data across different categories of the categorical data.
#
# a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots
#
#
# **Categorical - Categorical**
#
# a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.
# b. You can plots like heatmap, stacked barplots, treemaps
# Write your conclusions

# %%
df
# Out:
#       index  PatientID   age  gender   bmi  bloodpressure diabetic  children  \
# 0         0          1  39.0    male  23.2             91      Yes         0
# 1         1          2  24.0    male  30.1             87       No         0
# 7         7          8  19.0    male  41.1            100       No         0
# 8         8          9  20.0    male  43.0             86       No         0
# 9         9         10  30.0    male  53.1             97       No         0
# ...     ...        ...   ...     ...   ...            ...      ...       ...
# 1335   1335       1336  44.0  female  35.5             88      Yes         0
# 1336   1336       1337  59.0  female  38.1            120       No         1
# 1337   1337       1338  30.0    male  34.5             91      Yes         3
# 1338   1338       1339  37.0    male  30.4            106       No         0
# 1339   1339       1340  30.0  female  47.4            101       No         0
#
#      smoker     region     claim
# ...

# %% [markdown]
# Age and Claim
#
# Conclusions:
# 1. Highest claim amounts come from ages(20-25) people in early 20s
# 2. Then second highest claim amounts come from people above the age of 50(early 50s)
# 3. There is a very weak correlation between age and claims (as age increases, there is a very slight change in claims change)
# 4. Most claims come from ages between (30-50) with less than 15000 USD on average.
# 5. No general trend observed(stagnant mostly)

# %%
plt.figure(figsize=(40,20))
sns.relplot(kind='line',x=df['age'],y=df['claim'],legend='auto')

# %%
sns.displot(data=df, kind='hist',x='age',y='claim',cbar=True)

# %%
sns.displot(data=df, kind='kde',x='age',y='claim')

# %%
df['age'].corr(df['claim'])
# Out:
# np.float64(-0.028636389912437756)

# %% [markdown]
# Gender and claims

# %% [markdown]
# Conclusions:
# 1. The average claim amount for males and females is quite similar, with males appearing slightly higher, but the difference is not substantial.
# 2. Both genders exhibit a right-skewed distribution of claim amounts, meaning most claims are lower, with a few very high claims.
# 3. There are numerous outliers on the higher end of claim amounts for both males and females.
# 4. While the overall distribution shapes are similar, males might have a slightly wider spread in their claim amounts and potentially higher maximum claims compared to females.

# %%
sns.catplot(data=df,x='gender',y='claim',kind='bar')

# %%
sns.catplot(data=df,x='gender',y='claim',kind='box')

# %%
sns.catplot(data=df,x='gender',y='claim',kind='violin')

# %% [markdown]
# BMI and Claims
#
# Conclusions:
# 1. Highest claims come from people with bmi > 45.
# 2. Most claims are from people with a bmi between (20-40) with claim amounts less than 10000.
# 3. Bmi follows a weak positive correlation with the claim.(almost neglibile)
# 4. On average, claim amounts increase as bmi increases(Upward Trend).
# 5. The large variation shows that despite having a upward trend, there are a lot of people with high bmi but low claims so the bmi is not the only factor contributing to claim amounts.

# %%
sns.relplot(data=df,x='bmi',y='claim',kind='line')

# %%
sns.relplot(data=df,x='bmi',y='claim',kind='scatter')

# %%
sns.displot(data=df, kind='hist',x='bmi',y='claim',cbar=True)

# %%
df['bmi'].corr(df['claim'])
# Out:
# np.float64(0.19994510599944249)

# %% [markdown]
# BloodPressure and Claim
#
# Conclusions:
# 1. A obvious upward trend observed. People with high bloodpressure tend to have a significantly higher claims.
#
# 2. Generally, people have blood pressure 90=100 and have low claims between <15000
#
# 3. A relatively strong positive correlation observed between BloodPressure and Claim.
#
# 4. The distribution appears to right skewed.
#
# 5.  There seems to be a noticeable increase in both average claim and the occurrence of high claims once blood pressure surpasses approximately 100-110. This suggests a potential threshold where higher blood pressure starts to have a more pronounced impact on claim costs.

# %%
sns.relplot(data=df,x='bloodpressure',y='claim',kind='line')

# %%
sns.relplot(data=df,x='bloodpressure',y='claim',kind='scatter')

# %%
sns.displot(data=df,x='bloodpressure',y='claim',kind='hist',cbar=True)

# %%
sns.displot(data=df,x='bloodpressure',y='claim',kind='kde')

# %%
df['bloodpressure'].corr(df['claim'])
# Out:
# np.float64(0.5312634363168711)

# %% [markdown]
# Diabeties and Claims
#
# Conclusion:
# 1. Surprisingly, not Much of a difference between the claim amounts between diabetic and non diabetic
#
# 2. Both are right skewed, very few high claims.
#
# 3. Not much, but Non Diabetic patients have a higher greatest claim than Diabetic patients.

# %%
sns.catplot(data=df,x='diabetic',y='claim',kind='bar')

# %%
sns.catplot(data=df,x='diabetic',y='claim',kind='violin')

# %%
sns.catplot(data=df,x='diabetic',y='claim',kind='box')

# %% [markdown]
# Children and Claims
#
# Conclusions:
# 1. Highest avarage claim come from people having 2 or 3 children
# 2. Maximum claim amounts come from people having no children then second from people having 3 children.
# 3. As the number of  children increases to 4 or 5, the spread or range of the claims decreeases which means that high claims are less frequent with 4/5 children.
# 4. The average claim amount seems to decrease for individuals with 4 and 5 children, with those having 5 children showing the lowest average claim among all groups

# %%
sns.catplot(data=df,x='children',y='claim',kind='bar')

# %%
plt.figure(figsize=(20,5))
sns.catplot(data=df,x='children',y='claim',kind='violin')

# %%
sns.catplot(data=df,x='children',y='claim',kind='box')

# %% [markdown]
# Smoker and Claims
#
# Conclusions:
# 1. There is a significant difference between average claim amounts of smoker and non smokers with smokers havinf a higher claims than non smokers
# 2. Bimodal Right Skewed distribution for Smokers around (20000 and 40000)
# 3. Right Skewed for Non smokers as well.
# 4. Outliers for Non Smoker on greater side.
# 5. Smokers also have high maximum claims as compared to non smokers

# %%
sns.catplot(data=df,x='smoker',y='claim',kind='bar')
df.pivot_table(index='smoker',values='claim',aggfunc='mean')
# Out:
#                claim
# smoker
# No       8475.864537
# Yes     32050.231971

# %%
sns.catplot(data=df,x='smoker',y='claim',kind='violin')

# %%
sns.catplot(data=df,x='smoker',y='claim',kind='box')

# %% [markdown]
# Region and Claims
#
# Conclusions:
# 1. People from northeast make higher average claims, average claims from the other 3 regions are roughly equal.
# 2. All regions follow a right skewed distribution
# 3. Highest maximunm claims come from southeast and then northwest
# 4. SouthEast has the largest range/spread of claims
# 5. For each region, most claims are concentrated below 15000.
# 6. Though northeast has highest average claim, southeast show more variability in claims.

# %%
sns.catplot(data=df,x='region',y='claim',kind='bar')

# %%
sns.catplot(data=df,x='region',y='claim',kind='violin')

# %%
sns.catplot(data=df,x='region',y='claim',kind='box')

# %% [markdown]
# #Multivariate Analysis
#
# Conclusions:
# 1. People with High Blood Pressure have the highest claims on average
# 2. Broadly, people suffering from health complications have higher claims
# 3. Smokers have higher claims as compared to diabetic
# 4. People with no health complications have lower claims on average

# %%
df['bloodpressure_category'] = pd.cut(
    df['bloodpressure'],
    bins=[79, 90, 110, 140],
    labels=['Low (80-90)', 'Medium (91-110)', 'High (111-140)'],
    right=True
)
df['bloodpressure_category'].value_counts()
# Out:
# bloodpressure_category
# Medium (91-110)    671
# Low (80-90)        572
# High (111-140)      89
# Name: count, dtype: int64

# %%
sns.relplot(
    data=df,
    x='age',
    y='claim',
    col='smoker',
    row='diabetic',
    hue='bloodpressure_category',
    kind='line',
    height=4,
    aspect=1.2
)

# %%
g = sns.PairGrid(df, vars=['age', 'bmi', 'bloodpressure', 'claim'], hue='smoker', palette='tab10')
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()
plt.suptitle('Multivariate Analysis of Age, BMI, Bloodpressure, and Claim by Smoker Status', y=1.02)
plt.show()

# %%
corr_matrix = df[['age', 'bmi', 'bloodpressure', 'claim']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Healthcare Variables')
plt.show()
